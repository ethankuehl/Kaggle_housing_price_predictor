# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import LinearRegression, LassoCV, RidgeCV
from sklearn.preprocessing import StandardScaler

# %%
# null prediction is the mean of y
df = pd.read_csv('datasets/train.csv')

# %%
pd.set_option('display.max_rows', 999)
pd.set_option('display.max_columns', 999)

# %%
df.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 1       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
# 2       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 3       Reg          Lvl    AllPub     Inside        Gtl       Timber
# 4       IR1          Lvl    AllPub     Inside        Gtl      SawyerW
#
# ...

# %%
df.describe()
# Out:
#                 Id           PID  MS SubClass  Lot Frontage       Lot Area  \
# count  2051.000000  2.051000e+03  2051.000000   1721.000000    2051.000000
# mean   1474.033642  7.135900e+08    57.008776     69.055200   10065.208191
# std     843.980841  1.886918e+08    42.824223     23.260653    6742.488909
# min       1.000000  5.263011e+08    20.000000     21.000000    1300.000000
# 25%     753.500000  5.284581e+08    20.000000     58.000000    7500.000000
# 50%    1486.000000  5.354532e+08    50.000000     68.000000    9430.000000
# 75%    2198.000000  9.071801e+08    70.000000     80.000000   11513.500000
# max    2930.000000  9.241520e+08   190.000000    313.000000  159000.000000
#
#        Overall Qual  Overall Cond   Year Built  Year Remod/Add  Mas Vnr Area  \
# count   2051.000000   2051.000000  2051.000000     2051.000000   2029.000000
# mean       6.112140      5.562165  1971.708922     1984.190151     99.695909
# ...

# %%
df.dtypes
# Out:
# Id                   int64
# PID                  int64
# MS SubClass          int64
# MS Zoning           object
# Lot Frontage       float64
# Lot Area             int64
# Street              object
# Alley               object
# Lot Shape           object
# Land Contour        object
# Utilities           object
# Lot Config          object
# Land Slope          object
# Neighborhood        object
# Condition 1         object
# Condition 2         object
# Bldg Type           object
# House Style         object
# Overall Qual         int64
# Overall Cond         int64
# Year Built           int64
# Year Remod/Add       int64
# Roof Style          object
# Roof Matl           object
# Exterior 1st        object
# Exterior 2nd        object
# Mas Vnr Type        object
# Mas Vnr Area       float64
# Exter Qual          object
# Exter Cond          object
# Foundation          object
# Bsmt Qual           object
# Bsmt Cond           object
# Bsmt Exposure       object
# ...

# %%
df.isnull().sum()
# Out:
# Id                    0
# PID                   0
# MS SubClass           0
# MS Zoning             0
# Lot Frontage        330
# Lot Area              0
# Street                0
# Alley              1911
# Lot Shape             0
# Land Contour          0
# Utilities             0
# Lot Config            0
# Land Slope            0
# Neighborhood          0
# Condition 1           0
# Condition 2           0
# Bldg Type             0
# House Style           0
# Overall Qual          0
# Overall Cond          0
# Year Built            0
# Year Remod/Add        0
# Roof Style            0
# Roof Matl             0
# Exterior 1st          0
# Exterior 2nd          0
# Mas Vnr Type         22
# Mas Vnr Area         22
# Exter Qual            0
# Exter Cond            0
# Foundation            0
# Bsmt Qual            55
# Bsmt Cond            55
# Bsmt Exposure        58
# BsmtFin Type 1       55
# BsmtFin SF 1          1
# BsmtFin Type 2       56
# BsmtFin SF 2          1
# ...

# %%
df[df['Lot Frontage'].isna()]
# Out:
#         Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      109  533352170           60        RL           NaN     13517   Pave
# 7      145  535154050           20        RL           NaN     12160   Pave
# 8     1942  535353130           20        RL           NaN     15783   Pave
# 23      12  527165230           20        RL           NaN      7980   Pave
# 27    1534  909277040           50        RL           NaN     11700   Pave
# 31    2860  909276010           70        RL           NaN     11435   Pave
# 42     983  923275040           85        RL           NaN      9101   Pave
# 50    2511  533221080          160        FV           NaN      2998   Pave
# 59     997  527107010           60        RL           NaN     15038   Pave
# 62     230  905109170           20        RL           NaN     20062   Pave
# 71    1564  914453045           20        RL           NaN     23730   Pave
# ...

# %%
# Number of features that can be used as predictors
np.sqrt(2051)
# Out:
# 45.28796749689701

# %%
X_train = df[['Lot Area', 'Overall Cond', 'Bedroom AbvGr', 'Kitchen AbvGr', 'Half Bath', 
              'Bedroom AbvGr', 'Kitchen AbvGr', 'Wood Deck SF', 'Open Porch SF', 'Enclosed Porch', '3Ssn Porch', 
              'Screen Porch', 'Pool Area', '1st Flr SF', '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'MS SubClass',
             'Overall Qual', 'Year Built', 'Year Remod/Add', 'Full Bath', 'TotRms AbvGrd', 'Fireplaces', 
              'Misc Val','Mo Sold', 'Yr Sold']]

y_train = df['SalePrice']

# %%
sc = StandardScaler()

Z_train = sc.fit_transform(X_train)

# %%
lr = LinearRegression()
lr.fit(Z_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(Z_train,y_train)
# Out:
# 0.8160484114278556

# %%
df_test = pd.read_csv('datasets/test.csv')

# %%
X_test = df_test[['Lot Area', 'Overall Cond', 'Bedroom AbvGr', 'Kitchen AbvGr', 'Half Bath', 
              'Bedroom AbvGr', 'Kitchen AbvGr', 'Wood Deck SF', 'Open Porch SF', 'Enclosed Porch', '3Ssn Porch', 
              'Screen Porch', 'Pool Area', '1st Flr SF', '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'MS SubClass',
             'Overall Qual', 'Year Built', 'Year Remod/Add', 'Full Bath', 'TotRms AbvGrd', 'Fireplaces', 
              'Misc Val','Mo Sold', 'Yr Sold']]

# %%
lasso_alphas = np.logspace(0, 150, 250)

lasso = LassoCV(alphas=lasso_alphas, cv=5, max_iter=50000)

lasso.fit(Z_train, y_train)
# Out:
# LassoCV(alphas=array([1.00000000e+000, 4.00322167e+000, 1.60257837e+001, 6.41547646e+001,
#        2.56825744e+002, 1.02813038e+003, 4.11583382e+003, 1.64765951e+004,
#        6.59594626e+004, 2.64050350e+005, 1.05705208e+006, 4.23161379e+006,
#        1.69400880e+007, 6.78149274e+007, 2.71478187e+008, 1.08678736e+009,
#        4.35065070e+009, 1.74166192e+010, 6.97225872e+010, 2.79114972e+011,
#        1.117359...
#        2.23561796e+137, 8.94967427e+137, 3.58275299e+138, 1.43425544e+139,
#        5.74164246e+139, 2.29850675e+140, 9.20143202e+140, 3.68353720e+141,
#        1.47460159e+142, 5.90315705e+142, 2.36316462e+143, 9.46027181e+143,
#        3.78715651e+144, 1.51608270e+145, 6.06921511e+145, 2.42964134e+146,
#        9.72639286e+146, 3.89369066e+147, 1.55873068e+148, 6.23994444e+148,
#        2.49798808e+149, 1.00000000e+150]),
#         cv=5, max_iter=50000)

# %%
Z_test = sc.fit_transform(X_test)

# %%
lasso.score(Z_train, y_train)
# Out:
# 0.81251190910236

# %%
test_preds = lasso.predict(Z_test)

# %%
test_saleprice = pd.DataFrame(df_test['Id'])
test_saleprice['SalePrice'] = test_preds

# %%
test_saleprice
# Out:
#        Id      SalePrice
# 0    2658  132313.642674
# 1    2718  173097.470037
# 2    2414  212639.065367
# 3    1989  114293.807714
# 4     625  195500.327010
# 5     333   69239.478283
# 6    1327  117523.081673
# 7     858  157455.874984
# 8      95  186947.176842
# 9    1568  188193.375004
# 10   2482  164561.960407
# 11   1364  138179.239653
# 12   2584  171813.333973
# 13    818  247902.361788
# 14   2673  197363.811654
# 15   2089  171429.915406
# 16   1297  129573.424574
# 17    790  121103.461827
# 18   2616  244640.600157
# 19    720  192107.380212
# 20    222  160520.148013
# 21    557  105451.293580
# 22   1148  201962.393913
# 23   2766  165054.782486
# 24    534  209131.514826
# 25   1452  113028.480636
# 26    630  121179.401526
# 27   2648  132925.360855
# 28    125  142583.169765
# 29   1904    -608.860370
# 30   1670   93779.204191
# 31    756   69814.412429
# 32    717  233002.273363
# 33   1032  154663.738510
# 34    852  245839.064382
# 35   1731  199169.764143
# ...

# %%
test_saleprice.to_csv('output/prediction_6.csv', index=False)
